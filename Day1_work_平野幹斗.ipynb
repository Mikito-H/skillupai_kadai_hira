# %%
from matplotlib import pyplot

# %%
import math

# %%
import numpy as np

# %%
import pandas as pd

# %%
df = pd.read_csv('measurements.csv')

# %%
import pandas as pd

# %%
data = pd.read_csv("measurements.csv")

# %%
data
# Out:
#     distance consume  speed temp_inside  temp_outside specials gas_type  AC  \
# 0         28       5     26        21,5            12      NaN      E10   0
# 1         12     4,2     30        21,5            13      NaN      E10   0
# 2       11,2     5,5     38        21,5            15      NaN      E10   0
# 3       12,9     3,9     36        21,5            14      NaN      E10   0
# 4       18,5     4,5     46        21,5            15      NaN      E10   0
# 5        8,3     6,4     50        21,5            10      NaN      E10   0
# 6        7,8     4,4     43        21,5            11      NaN      E10   0
# 7       12,3       5     40        21,5             6      NaN      E10   0
# 8        4,9     6,4     26        21,5             4      NaN      E10   0
# 9       11,9     5,3     30        21,5             9      NaN      E10   0
# 10      12,4     5,6     42        21,5             4      NaN      E10   0
# ...

# %%
data.columns
# Out:
# Index(['distance', 'consume', 'speed', 'temp_inside', 'temp_outside',
#        'specials', 'gas_type', 'AC', 'rain', 'sun', 'refill liters',
#        'refill gas'],
#       dtype='object')

# %%
data.distance
# Out:
# 0        28
# 1        12
# 2      11,2
# 3      12,9
# 4      18,5
# 5       8,3
# 6       7,8
# 7      12,3
# 8       4,9
# 9      11,9
# 10     12,4
# 11     11,8
# 12     12,3
# 13     24,7
# 14     12,4
# 15     17,3
# 16     33,4
# 17     11,8
# 18     25,9
# 19     11,8
# 20     25,3
# 21     14,2
# 22     17,9
# 23     11,8
# 24     12,3
# 25     12,4
# 26     18,4
# 27     18,4
# 28     18,3
# 29     18,4
#        ...
# 358     6,1
# 359    17,3
# 360       6
# 361      16
# 362    15,4
# 363    15,4
# 364      16
# 365    15,4
# 366    16,6
# 367    15,4
# 368      16
# 369    15,4
# 370      16
# 371    20,9
# 372    32,1
# 373    15,3
# 374    28,5
# 375    11,9
# 376    14,5
# 377    16,6
# 378    16,2
# 379    16,7
# 380     8,3
# 381     5,5
# 382    13,6
# 383      16
# 384    16,1
# 385      16
# 386    15,4
# 387    14,7
# Name: distance, Length: 388, dtype: object

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
data_col = data.columns

# %%
#グラフの作成
plt.figure(1)
plt.plot(data[data_col[0]],data[data_col[1]],marker="o")

#グラフの軸
plt.xlabel(data[data_col[0]].name)
plt.ylabel(data[data_col[1]].name)
# Out:
# Text(0, 0.5, 'consume')

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
import seaborn as sns
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D #3D散布図の描画

# %%
data.describe()
# Out:
#             speed  temp_outside          AC        rain         sun
# count  388.000000    388.000000  388.000000  388.000000  388.000000
# mean    41.927835     11.358247    0.077320    0.123711    0.082474
# std     13.598524      6.991542    0.267443    0.329677    0.275441
# min     14.000000     -5.000000    0.000000    0.000000    0.000000
# 25%     32.750000      7.000000    0.000000    0.000000    0.000000
# 50%     40.500000     10.000000    0.000000    0.000000    0.000000
# 75%     50.000000     16.000000    0.000000    0.000000    0.000000
# max     90.000000     31.000000    1.000000    1.000000    1.000000

# %%
pd.plotting.scatter_matrix(data, figsize=(20,20))
plt.show()

# %%
data.corr()
# Out:
#                  speed  temp_outside        AC      rain       sun
# speed         1.000000      0.015411 -0.035408  0.009489  0.081618
# temp_outside  0.015411      1.000000  0.167562 -0.186315  0.346903
# AC           -0.035408      0.167562  1.000000  0.242915  0.088598
# rain          0.009489     -0.186315  0.242915  1.000000 -0.112650
# sun           0.081618      0.346903  0.088598 -0.112650  1.000000

# %%
sns.heatmap(data.corr())
plt.show()

# %%
data_col = data.columns

# %%
data[data_col[0]]
# Out:
# 0        28
# 1        12
# 2      11,2
# 3      12,9
# 4      18,5
# 5       8,3
# 6       7,8
# 7      12,3
# 8       4,9
# 9      11,9
# 10     12,4
# 11     11,8
# 12     12,3
# 13     24,7
# 14     12,4
# 15     17,3
# 16     33,4
# 17     11,8
# 18     25,9
# 19     11,8
# 20     25,3
# 21     14,2
# 22     17,9
# 23     11,8
# 24     12,3
# 25     12,4
# 26     18,4
# 27     18,4
# 28     18,3
# 29     18,4
#        ...
# 358     6,1
# 359    17,3
# 360       6
# 361      16
# 362    15,4
# 363    15,4
# 364      16
# 365    15,4
# 366    16,6
# 367    15,4
# 368      16
# 369    15,4
# 370      16
# 371    20,9
# 372    32,1
# 373    15,3
# 374    28,5
# 375    11,9
# 376    14,5
# 377    16,6
# 378    16,2
# 379    16,7
# 380     8,3
# 381     5,5
# 382    13,6
# 383      16
# 384    16,1
# 385      16
# 386    15,4
# 387    14,7
# Name: distance, Length: 388, dtype: object

# %%
data = pd.read_csv("measurements.csv").values.tolist()

# %%
data
# Out:
# [['28', '5', 26, '21,5', 12, nan, 'E10', 0, 0, 0, '45', 'E10'],
#  ['12', '4,2', 30, '21,5', 13, nan, 'E10', 0, 0, 0, nan, nan],
#  ['11,2', '5,5', 38, '21,5', 15, nan, 'E10', 0, 0, 0, nan, nan],
#  ['12,9', '3,9', 36, '21,5', 14, nan, 'E10', 0, 0, 0, nan, nan],
#  ['18,5', '4,5', 46, '21,5', 15, nan, 'E10', 0, 0, 0, nan, nan],
#  ['8,3', '6,4', 50, '21,5', 10, nan, 'E10', 0, 0, 0, nan, nan],
#  ['7,8', '4,4', 43, '21,5', 11, nan, 'E10', 0, 0, 0, nan, nan],
#  ['12,3', '5', 40, '21,5', 6, nan, 'E10', 0, 0, 0, nan, nan],
#  ['4,9', '6,4', 26, '21,5', 4, nan, 'E10', 0, 0, 0, nan, nan],
#  ['11,9', '5,3', 30, '21,5', 9, nan, 'E10', 0, 0, 0, nan, nan],
#  ['12,4', '5,6', 42, '21,5', 4, nan, 'E10', 0, 0, 0, nan, nan],
#  ['11,8', '4,6', 38, '21,5', 0, nan, 'E10', 0, 0, 0, nan, nan],
#  ['12,3', '5,9', 59, '21,5', 10, nan, 'E10', 0, 0, 0, nan, nan],
#  ['24,7', '5,1', 58, '21,5', 12, nan, 'E10', 0, 0, 0, nan, nan],
#  ['12,4', '4,7', 46, '21,5', 11, nan, 'E10', 0, 0, 0, nan, nan],
# ...

# %%
data2 = []
for i in range(len(data)):
    new_str = str(data[i].replace(",","."))
    data2.append(new_str)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-43-5f64ee73c0ea> in <module>
#       1 data2 = []
#       2 for i in range(len(data)):
# ----> 3     new_str = str(data[i].replace(",","."))
#       4     data2.append(new_str)
#
# AttributeError: 'list' object has no attribute 'replace'

# %%
data
# Out:
# [['28', '5', 26, '21,5', 12, nan, 'E10', 0, 0, 0, '45', 'E10'],
#  ['12', '4,2', 30, '21,5', 13, nan, 'E10', 0, 0, 0, nan, nan],
#  ['11,2', '5,5', 38, '21,5', 15, nan, 'E10', 0, 0, 0, nan, nan],
#  ['12,9', '3,9', 36, '21,5', 14, nan, 'E10', 0, 0, 0, nan, nan],
#  ['18,5', '4,5', 46, '21,5', 15, nan, 'E10', 0, 0, 0, nan, nan],
#  ['8,3', '6,4', 50, '21,5', 10, nan, 'E10', 0, 0, 0, nan, nan],
#  ['7,8', '4,4', 43, '21,5', 11, nan, 'E10', 0, 0, 0, nan, nan],
#  ['12,3', '5', 40, '21,5', 6, nan, 'E10', 0, 0, 0, nan, nan],
#  ['4,9', '6,4', 26, '21,5', 4, nan, 'E10', 0, 0, 0, nan, nan],
#  ['11,9', '5,3', 30, '21,5', 9, nan, 'E10', 0, 0, 0, nan, nan],
#  ['12,4', '5,6', 42, '21,5', 4, nan, 'E10', 0, 0, 0, nan, nan],
#  ['11,8', '4,6', 38, '21,5', 0, nan, 'E10', 0, 0, 0, nan, nan],
#  ['12,3', '5,9', 59, '21,5', 10, nan, 'E10', 0, 0, 0, nan, nan],
#  ['24,7', '5,1', 58, '21,5', 12, nan, 'E10', 0, 0, 0, nan, nan],
#  ['12,4', '4,7', 46, '21,5', 11, nan, 'E10', 0, 0, 0, nan, nan],
# ...
